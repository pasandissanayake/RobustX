# %% [markdown]
# # Benchmarking different methods
#
# This notebook presents a pipeline to run CEs benchmarking in an example dataset.
#
# We use the ```default_benchmark()``` function which is an example pipeline defined in lib/DefaultBenchmark.py. One can instantiate similar functions for compact benchmarking.

# %%
# first load a dataset and train a neural network, create task

from robustx.datasets.ExampleDatasets import get_example_dataset
from robustx.lib.models.pytorch_models.OriginalSimpleNNModel import OriginalSimpleNNModel
from robustx.lib.tasks.ClassificationTask import ClassificationTask

model = OriginalSimpleNNModel(input_dim=34, hidden_dim=[8], output_dim=1)
dl = get_example_dataset("ionosphere")
dl.default_preprocess()
model.train(dl.X, dl.y)
task = ClassificationTask(model, dl)

# %%
# speccify the names of the methods and evaluations we want to use, run benchmarking
# This will find CEs for all instances predicted with the undesirable class (0) and compare

from robustx.lib.DefaultBenchmark import default_benchmark
methods = ["KDTreeNNCE", "Wachter", "EntropicRiskCE"]
evaluations = ["Validity", "Distance"]
default_benchmark(task, methods, evaluations, neg_value=0, column_name="target", delta=0.005)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 7
#       5 methods = ["KDTreeNNCE", "Wachter", "EntropicRiskCE"]
#       6 evaluations = ["Validity", "Distance"]
# ----> 7 default_benchmark(task, methods, evaluations, neg_value=0, column_name="target", delta=0.005)
#
# File /export/pasand/smiles/RobustX/robustx/lib/DefaultBenchmark.py:60, in default_benchmark(ct, methods, evaluations, subset, **params)
#      58 # Generate CEs
#      59 if subset is None:
# ---> 60     ces = ce_generator.generate_for_all(**params)
#      61 else:
#      62     ces = ce_generator.generate(subset, **params)
#
# File /export/pasand/smiles/RobustX/robustx/generators/CEGenerator.py:90, in CEGenerator.generate_for_all(self, neg_value, column_name, **kwargs)
#      78 negatives = self.task.get_negative_instances(neg_value, column_name=column_name)
#      79 # preds = self.task.model.predict(self.task.training_data.X).values.flatten()
#      80 #
#      81 # if neg_value == 0:
#    (...)
#      87 #     negatives = self.task.training_data.data.drop(columns=[column_name])
#      88 #     negatives = pd.DataFrame(negatives.values[idxs], columns=negatives.columns)
# ---> 90 counterfactuals = self.generate(
#      91     negatives,
#      92     column_name=column_name,
#      93     neg_value=neg_value,
#      94     **kwargs
#      95 )
#      97 counterfactuals.index = negatives.index
#      98 return counterfactuals
#
# File /export/pasand/smiles/RobustX/robustx/generators/CEGenerator.py:47, in CEGenerator.generate(self, instances, neg_value, column_name, **kwargs)
#      44 cs = []
#      46 for _, instance in instances.iterrows():
# ---> 47     cs.append(self.generate_for_instance(instance, neg_value=neg_value,
#      48                                          column_name=column_name, **kwargs))
#      50 res = pd.concat(cs)
#      52 return res
#
# File /export/pasand/smiles/RobustX/robustx/generators/CEGenerator.py:66, in CEGenerator.generate_for_instance(self, instance, neg_value, column_name, **kwargs)
#      54 def generate_for_instance(self, instance, neg_value=0,
#      55                           column_name="target", **kwargs) -> pd.DataFrame:
#      56     """
#      57     Generates a counterfactual for a provided instance.
#      58
#    (...)
#      63     @return: A DataFrame containing the counterfactual explanations for the instance.
#      64     """
# ---> 66     return self._generation_method(instance, neg_value=neg_value, column_name=column_name, **kwargs)
#
# File /export/pasand/smiles/RobustX/robustx/generators/robust_CE_methods/EntropicRiskCE.py:158, in EntropicRiskCE._generation_method(self, instance, target_class, loss_fn, target_weights, project_to_range, permitted_ranges, immutable_features, max_iter, theta, tau, lr, device, verbose, **kwargs)
#     152 optimiser.zero_grad()
#     154 # For multiclass classification, predict_ensemble_proba_tensor returns shape: (n_models, batch_size[=1], n_classes)
#     155 # For binary classification, predict_ensemble_proba_tensor shape: (n_models, batch_size[=1], 1)
#     156 # Either case, we need to extract the probabilities for the target class and the resultant
#     157 # class_prob should have shape: (n_models, batch_size)
# --> 158 preds = self.task.model.predict_ensemble_proba_tensor(ent_ce)
#     160 if isinstance(preds, torch.Tensor):
#     161     if preds.shape[2] >= 2:
#
# AttributeError: 'OriginalSimpleNNModel' object has no attribute 'predict_ensemble_proba_tensor'
